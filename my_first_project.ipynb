# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratan-sarkar07/My-first-project/blob/main/my_first_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("bangladesh")
# Out:
# bangladesh

# %%
print(" Welcome to Bangladesh.")
# Out:
#  Welcome to Bangladesh.
